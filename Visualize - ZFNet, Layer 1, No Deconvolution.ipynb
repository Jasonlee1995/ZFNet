# %%
import model, torch
import matplotlib.pyplot as plt
from torchvision.utils import make_grid

# %%
num_classes = 10
ZFNet = model.ZFNet(num_classes=num_classes)

weight_file = './best.pt'
ZFNet.load_state_dict(torch.load(weight_file))
# Out:
# <All keys matched successfully>

# %%
ZFNet.conv1[0]
# Out:
# Conv2d(3, 96, kernel_size=(7, 7), stride=(2, 2), padding=(1, 1))

# %%
kernels = ZFNet.conv1[0].weight.detach().clone()
kernels = kernels - kernels.min()
kernels = kernels / kernels.max()

# %%
img = make_grid(kernels)

plt.figure(figsize=(25, 25))
plt.axis('off')
plt.imshow(img.permute(1, 2, 0))
